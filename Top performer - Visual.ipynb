# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('C:/Users/x.zheng/OneDrive - EXPONDO/Desktop/data_input5.csv', header = 0, index_col = 0)

# %%
plt.figure(figsize=(12,8))
sns.distplot(df1['CM1'],bins=80)
# Out:
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CM1', ylabel='Density'>

# %%
df2=df1.fillna(0).drop(['CM2','SPI','%CM2','#DayDiff_CreateDate',
                             '#DayDiff_ReleaseDate','#DayDiff_ReleaseDate',
                              'M_ROI', 'PuchasePrice',
                              'Avg_GaProductViewsNormalized','Avg_ProductViewsCR',
                              'GaProductUniquePurchases', 'WA_GaProductViewsNormalized', '#DeliverCountry',
                              'WA_NProductViewsCR','SumGSC_Impression', '#Shops'],axis = 1)

# %%
df2.columns
# Out:
# Index(['Rank', 'Top Skus', 'ABC/XYZ', 'ΣSalesNetValueUnit',
#        'ShopΣSalesNetValueUnit', '#DayDiff_DeliveryDate',
#        '#DayDiff_FirstSalesDate', 'FirstSalesDate', 'Seasonality', 'Quantity',
#        'CM1', 'CM1_Shop', '%CM1', '%TargetMargin', 'Price',
#        '%CustomerRepeatRate', '%ConversionRate_byOrderDate', '%OOSbyorderdate',
#        '#CaseUnique_byOrderDate', '%ProductClaim_CaseUnique', '%ReturnRate',
#        'NPS_byOrderDate', 'MarketingAds', 'ForecastAccuracyMAPE',
#        'ForecastAccuracyWAPE', 'SupplierScore', '#MainChannel',
#        '#TtlSubChannel', 'SumGSC_Click', 'WA_GSC_AvgPosition', 'WA_MonSearch',
#        'CompetitionLevel', '#PositiveReview', '#TtlPositiveReview',
#        'PositiveReviewRate', 'OrderStatus', 'MainCategory'],
#       dtype='object')

# %%
df3=df2.drop([ 'ShopΣSalesNetValueUnit', 'CM1','Seasonality', 'Quantity',  'CM1_Shop', '%CM1',
       'Price', '%CustomerRepeatRate', '%ConversionRate_byOrderDate','#CaseUnique_byOrderDate',
       '%OOSbyorderdate', 'NPS_byOrderDate',
       'ForecastAccuracyMAPE',
       'SupplierScore', '#MainChannel', '#TtlSubChannel',
       'WA_GSC_AvgPosition', 'WA_MonSearch'], axis =1)

# %% [markdown]
# ### '#DayDiff_DeliveryDate', '%ReturnRate', 'MarketingAds', '#PositiveReview', 'ForecastAccuracyWAPE', 'SumGSC_Click'

# %%
df3.columns
# Out:
# Index(['Rank', 'Top Skus', 'ABC/XYZ', 'ΣSalesNetValueUnit',
#        '#DayDiff_DeliveryDate', '#DayDiff_FirstSalesDate', 'FirstSalesDate',
#        '%TargetMargin', '%ProductClaim_CaseUnique', '%ReturnRate',
#        'MarketingAds', 'ForecastAccuracyWAPE', 'SumGSC_Click',
#        'CompetitionLevel', '#PositiveReview', '#TtlPositiveReview',
#        'PositiveReviewRate', 'OrderStatus', 'MainCategory'],
#       dtype='object')

# %%
g=sns.PairGrid(df3)
g.map(plt.scatter)

# %%
df4=df2.drop([ 'ΣSalesNetValueUnit','ShopΣSalesNetValueUnit', 'Seasonality', 'Quantity',  'CM1_Shop', '%CM1',
       'Price', '%CustomerRepeatRate', '%ConversionRate_byOrderDate','#CaseUnique_byOrderDate',
       '%OOSbyorderdate', 'NPS_byOrderDate',
       'ForecastAccuracyMAPE',
       'SupplierScore', '#MainChannel', '#TtlSubChannel',
       'WA_GSC_AvgPosition', 'WA_MonSearch'], axis =1)

# %%
g=sns.PairGrid(df4)
g.map(plt.scatter)

# %% [markdown]
# ### #DayDiff_DeliveryDate

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x='#DayDiff_FirstSalesDate', y='ΣSalesNetValueUnit', data=df2,
           hue='Top Skus' )

# %%
g = sns.FacetGrid(df2, col='Top Skus',hue = 'Top Skus')
g = g.map(plt.scatter, '#DayDiff_DeliveryDate','ΣSalesNetValueUnit').add_legend()

# %% [markdown]
# ### Target Margin

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x='%TargetMargin', y='ΣSalesNetValueUnit', data=df2, 
           hue='Top Skus',aspect=1.5,size=4)
# Out:
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x='%TargetMargin', y='ΣSalesNetValueUnit', data=df2, aspect=1.5,size=4)
# Out:
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Product claim%

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x='%ProductClaim_CaseUnique', y='ΣSalesNetValueUnit', data=df2, 
        aspect=1.5,size=4)
# hue='Top Skus',
# Out:
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Marketing Ads spending

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x='MarketingAds', y='ΣSalesNetValueUnit', data=df2, hue='Top Skus', aspect=1.5,size=4)
# Out:
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x='MarketingAds', y='CM1', data=df2, hue='Top Skus', aspect=1.5,size=6)
# Out:
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### ForecastAccuracyWAPE

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x='ForecastAccuracyWAPE', y='ΣSalesNetValueUnit', data=df2, hue='Top Skus')

# %% [markdown]
# #### PositiveReview

# %%
plt.figure(figsize=(20,15))
sns.lmplot(x='#PositiveReview', y='ΣSalesNetValueUnit', data=df2, hue='Top Skus', aspect=1.5,size=4)
# Out:
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Price = Product Value
# * now the analysis is based on different product, --> referring to the Product value --> check the density
# * pricing impact shall be one product to analysis the price vs quantity
# * to add price elasticity + price flucation

# %%
plt.figure(figsize=(12,8))
sns.lmplot(x='Price', y='ΣSalesNetValueUnit', data=df2 ,hue='Top Skus' )

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Price', y='Quantity', data=df2 ,hue='ABC/XYZ' )
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Quantity'>

# %%
df2.columns
# Out:
# Index(['ΣSalesNetValueUnit', 'ShopΣSalesNetValueUnit', '#DayDiff_DeliveryDate',
#        'Seasonality', 'CM1_Shop', '%CM1', '%TargetMargin', 'Price',
#        '%CustomerRepeatRate', '%ConversionRate_byOrderDate', '%OOSbyorderdate',
#        '#CaseUnique_byOrderDate', '%ProductClaim_CaseUnique', '%ReturnRate',
#        'NPS_byOrderDate', 'MarketingAds', 'ForecastAccuracyMAPE',
#        'ForecastAccuracyWAPE', 'SupplierScore', '#MainChannel',
#        '#TtlSubChannel', 'SumGSC_Click', 'WA_GSC_AvgPosition', 'WA_MonSearch',
#        '#PositiveReview', 'OrderStatus', 'MainCategory', 'Top Skus',
#        'ABC/XYZ'],
#       dtype='object')

# %%
Top75 = df2[df2['Top Skus']=='TOP 75']

# %%
plt.figure(figsize=(18,8))
sns.swarmplot(x='MainCategory', y='ΣSalesNetValueUnit',hue='ABC/XYZ',
             data=df2, palette="Set1",  split= False)
# Out:
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\categorical.py:2999: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\x.zheng\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
Top75.columns
# Out:
# Index(['ΣSalesNetValueUnit', '#DayDiff_DeliveryDate', 'Seasonality', '%CM1',
#        '%TargetMargin', 'Price', '%CustomerRepeatRate',
#        '%ConversionRate_byOrderDate', '%OOSbyorderdate',
#        '#CaseUnique_byOrderDate', '%ProductClaim_CaseUnique',
#        'NPS_byOrderDate', 'MarketingAds', 'ForecastAccuracyMAPE',
#        'ForecastAccuracyWAPE', 'SupplierScore', '#MainChannel',
#        '#TtlSubChannel', 'SumGSC_Click', 'WA_GSC_AvgPosition', 'WA_MonSearch',
#        'OrderStatus', 'MainCategory', 'Top Skus'],
#       dtype='object')
